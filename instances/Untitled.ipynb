# %%
import os
import json
from src.toy_4bus_2LECs import build_toy_4bus_2LECs

DATA_DIR = "data"

pdata = build_toy_4bus_2LECs(os.path.join(DATA_DIR, "toy_4bus_2LECs"), start_date = '2023-01-01',
                         end_date = '2023-01-07', frequency = '1min') # frequency = '1h' for hour

pdata.system_dict()
# Out:
# {'host_grid': {'demands': {0: {'index': 0,
#     'name': None,
#     'bus': 2,
#     'snom_MVA': 0.447,
#     'pnom_MW': 0.4,
#     'qnom_MVAr': 0.2,
#     'p_MW': {'tsname': 'ds_p_MW0', 'default': 0.4},
#     'q_MVAr': {'tsname': 'ds_q_MVAr0', 'default': 0.2}},
#    1: {'index': 1,
#     'name': None,
#     'bus': 3,
#     'snom_MVA': 0.447,
#     'pnom_MW': 0.4,
#     'qnom_MVAr': 0.2,
#     'p_MW': {'tsname': 'ds_p_MW1', 'default': 0.4},
#     'q_MVAr': {'tsname': 'ds_q_MVAr1', 'default': 0.2}},
#    2: {'index': 2,
#     'name': None,
#     'bus': 4,
#     'snom_MVA': 0.447,
#     'pnom_MW': 0.4,
#     'qnom_MVAr': 0.2,
#     'p_MW': {'tsname': 'ds_p_MW2', 'default': 0.4},
#     'q_MVAr': {'tsname': 'ds_q_MVAr2', 'default': 0.2}}},
#   'generators': {},
#   'buses': {1: {'index': 1, 'name': None, 'vnom_kV': 12.5, 'bustype': 0},
#    2: {'index': 2, 'name': None, 'vnom_kV': 12.5, 'bustype': 1},
#    3: {'index': 3, 'name': None, 'vnom_kV': 12.5, 'bustype': 1},
#    4: {'index': 4, 'name': None, 'vnom_kV': 12.5, 'bustype': 1}},
#   'branches': {0: {'index': 0,
#     'name': None,
#     'busf': 2,
#     'bust': 3,
#     'r_pu': 0.016200000000000003,
#     'x_pu': 0.006,
#     'b_pu': 0.0,
#     'snom_MVA': 999},
#    1: {'index': 1,
#     'name': None,
#     'busf': 1,
#     'bust': 2,
#     'r_pu': 0.016200000000000003,
#     'x_pu': 0.006,
#     'b_pu': 0.0,
#     'snom_MVA': 999},
#    2: {'index': 2,
#     'name': None,
#     'busf': 4,
#     'bust': 1,
#     'r_pu': 0.016200000000000003,
#     'x_pu': 0.006,
#     'b_pu': 0.0,
#     'snom_MVA': 999}},
#   'inv_branches': {0: {'cost_investment': 1000.0,
#     'cost_maintenance': 0.0,
#     'index': 0,
#     'name': None,
#     'busf': 1,
#     'bust': 2,
#     'r_pu': 0.0162,
#     'x_pu': 0.006,
#     'b_pu': 0.0,
#     'snom_MVA': 999.0}},
#   'inv_generators': {},
#   'params': {'name': None, 'index': None, 'sbase_MVA': 1.0}},
#  'lecs': {1: {'demands': {0: {'index': 0,
#      'name': None,
#      'bus': 4,
#      'snom_MVA': 0.08940000000000001,
#      'pnom_MW': 0.08000000000000002,
#      'qnom_MVAr': 0.04000000000000001,
#      'p_MW': {'tsname': 'lec1_p_MW0', 'default': 0.4},
#      'q_MVAr': {'tsname': 'lec1_q_MVAr0', 'default': 0.2}}},
#    'generators': {0: {'index': 0,
#      'name': None,
#      'bus': 0,
#      'snom_MVA': 0.5,
#      'pfmin': None,
#      'pmax_MW': {'tsname': 'lec1_p_MW0', 'default': 0.5}}},
#    'buses': {},
#    'branches': {},
#    'inv_branches': {},
#    'inv_generators': {0: {'cost_investment': 1000.0,
#      'cost_maintenance': 50.0,
#      'index': 0,
#      'name': None,
#      'bus': 0,
#      'snom_MVA': 0.5,
#      'pfmin': None,
#      'pmax_MW': {'tsname': 'ds_p_MW1', 'default': 0.5}}},
#    'params': {'name': 'LEC 1',
#     'index': None,
#     'sbase_MVA': None,
#     'host_bus_idx': 1,
#     'reinforcement': [0.1, 0.2, 0.3]}},
#   2: {'demands': {0: {'index': 0,
#      'name': None,
#      'bus': 4,
#      'snom_MVA': 0.08940000000000001,
#      'pnom_MW': 0.08000000000000002,
#      'qnom_MVAr': 0.04000000000000001,
#      'p_MW': {'tsname': 'lec2_p_MW0', 'default': 0.4},
#      'q_MVAr': {'tsname': 'lec2_q_MVAr0', 'default': 0.2}}},
#    'generators': {0: {'index': 0,
#      'name': None,
#      'bus': 0,
#      'snom_MVA': 0.5,
#      'pfmin': None,
#      'pmax_MW': {'tsname': 'lec2_p_MW0', 'default': 0.5}}},
#    'buses': {},
#    'branches': {},
#    'inv_branches': {},
#    'inv_generators': {0: {'cost_investment': 1000.0,
#      'cost_maintenance': 50.0,
#      'index': 0,
#      'name': None,
#      'bus': 0,
#      'snom_MVA': 0.5,
#      'pfmin': None,
#      'pmax_MW': {'tsname': 'ds_p_MW1', 'default': 0.5}}},
#    'params': {'name': 'LEC 2',
#     'index': None,
#     'sbase_MVA': None,
#     'host_bus_idx': 2,
#     'reinforcement': [0.1, 0.2, 0.3]}}},
#  'time_config': {'start': '2023-01-01T00:00:00',
#   'end': '2023-01-07T00:00:00',
#   'periods': None,
#   'freq': '1min',
#   'tz': None}}

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pdata.tsdata[1]

# Plotting the DataFrame
plt.figure(figsize=(10, 6))
for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
